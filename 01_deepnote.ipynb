# %% [markdown]
# > print\("Mi primer notebook en Deepnote"\)

# %%
print("Mi primer notebook en Deepnote")
# Out:
# Mi primer notebook en Deepnote

# %% [markdown]
# Mi nombre es Enzo, tengo 24 años y estudio en el IFTS N°24

# %% [markdown]
# Trabajo en una empresa en el rubro IT, mi puesto es Analista de fraude

# %% [markdown]
# El nombre de la materia es muy llamativo y tengo ganas de aprender y sumar conocimientos nuevos

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2f7df5bd-75cc-49b1-892f-1f34013b361d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
